# %% [markdown]
# > 💡 *Before running: select the right kernel **`Python (ai4bio-gpu)`** from the Kernel picker in the top-right corner. If not, click it and switch.*

# %% [markdown]
# This is a notebook to check if all functions are imported, and if the DelftBlue setup works as intended. Just run the code below. It might take <5 minutes if everything goes well. It checks for imports and whether the files present on common DelftBlue storage are accessible.

# %%
from src.delftblue_check import check_everything

check_everything()
