# %% [markdown]
# # Module 2: Image data — Convolutional Neural Networks
#
#
# - Recognize that images have spatial structure (locality + translation equivariance)
# (What is a good way to show this?)
# - Understand the convolution operation
# (1-D and 2-D operations)
# - Show how convolution kernels can learn spatial structure
# (Edge detection, design your own kernel etc)
# - See empirically that a CNN learns from less data than an FC for image tasks
# (Use the same MNIST data for CNN or use CIFAR for more complex images)
# - Show kernels that are learned by the CNN and connect to the spatial structure of the data
# - Connect to inductive bias from Module 1

# %% [markdown]
# ## 1. What is an image?
#
# - Show how image is a 2D array of pixel values (grayscale) or a 3D array (color images with RGB channels).
# - What structures can you see from the image (horizontal edge, corners, stripies etc)? How can you tell these structures from the pixel values alone?

# %% [markdown]
# ## 2. What is convolution?
#
# - Show 1-D convolution as a slider from the earlier notebook
# - Apply 2-D convolution to extract different structures
# (Edge detection, design your own kernel etc)

# %% [markdown]
# ## 3. What is a CNN?
#
# A CNN is a deep neural network which learns spatial structure in the data by learning the weights of a convolutional kernel
#
# - Show how the convolution operation is applied to an image (slide a kernel across the image and compute the dot product at each location).

# %% [markdown]
# ## 4. Build a CNN
#
# <!-- Pointer:
#      - Architecture: a few conv layers (with ReLU + pooling), then flatten, then a small FC head
#      - Same training loop as Module 1
#      - Same hyperparameter knobs at the top
# -->

# %%
class CNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        # TODO: define

        pass

    def forward(self, x):

        pass

# %% [markdown]
# ## 5. Experiment: CNN vs FC sample efficiency
#
# Copy and paste the FC model class from Module 1
#
# 1) Create an instance of the CNN and the FC model. Number of parameters for CNN ~5k and that for FC ~50k
#
# 2) Train both models on subsets of the training data: 1%, 5%, 25%, 100%
# (What should be the epoch size? Keep hyperparameters in both as similar as possible, except for the architecture)
#
# 3) Plot test accuracy vs training set size for both models
#
# That is the evidence of inductive bias in CNNs: they can learn from less data than FCs for image tasks because they leverage the spatial structure of the data.

# %% [markdown]
# ## 6. Discussion
#
# Assignment?
# - Does CNN work better on hand-drawn digits?
